# %% [markdown]
# # KGQA Research: High-Intensity Benchmark Runner
#
# Use this notebook to run memory-intensive or long-running experiments in parallel using Colab GPUs (A100/H100 recommended for Exp 7).
#
# **Instructions:**
# 1. Zip your local project: `kgqaHierarchical.zip`
# 2. Upload to the Colab runtime (or your Google Drive).
# 3. Run the setup and training cells below.

# %%
# 1. Setup Environment
# !pip install transformers tqdm torch
# !unzip -q kgqaHierarchical.zip -d .
# %cd kgqaHierarchical
import os
os.environ['PYTHONPATH'] = os.getcwd()
print("Environment ready.")

# %% [markdown]
# ## Select and Run Experiment
# Change the script path to run different Phase 2 experiments.

# %%
# RE-RUN SUITE (Choose one or all)
# !python train/exp7_roberta.py  # Recommended for A100/H100
# !python train/exp6_unified.py
# !python train/exp4_rl.py
